# %% [markdown]
# <a href="https://colab.research.google.com/github/FatemeMolaeiJahromi/FatemeMolaeiJahromi/blob/Leishmania-Classification/Tri_Leishmania_Classification_Molaei.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-fuzzy
# Out:
# Requirement already satisfied: scikit-fuzzy in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (1.23.5)
# Requirement already satisfied: scipy>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (1.11.4)
# Requirement already satisfied: networkx>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from scikit-fuzzy) (3.2.1)

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl

# Define the fuzzy variables
amastigote_result = ctrl.Antecedent(np.arange(0, 101, 1), 'amastigote_result')
fields = ctrl.Antecedent(np.arange(0, 31, 1), 'fields')
diagnosis = ctrl.Consequent(np.arange(0, 4, 1), 'diagnosis')

# Define the fuzzy sets for each variable
amastigote_result['low'] = fuzz.trimf(amastigote_result.universe, [0, 5, 10])
amastigote_result['medium'] = fuzz.trimf(amastigote_result.universe, [5, 15, 25])
amastigote_result['high'] = fuzz.trimf(amastigote_result.universe, [20, 50, 100])

fields['low'] = fuzz.trimf(fields.universe, [0, 5, 10])
fields['medium'] = fuzz.trimf(fields.universe, [5, 10, 15])
fields['high'] = fuzz.trimf(fields.universe, [10, 20, 30])

diagnosis['grade1'] = fuzz.trimf(diagnosis.universe, [0, 0, 0])
diagnosis['grade2'] = fuzz.trimf(diagnosis.universe, [1, 1, 1])
diagnosis['grade3'] = fuzz.trimf(diagnosis.universe, [2, 2, 2])
diagnosis['grade4'] = fuzz.trimf(diagnosis.universe, [3, 3, 3])

# Step 3.5: Plot the fuzzy membership functions
amastigote_result.view()
fields.view()
diagnosis.view()

# Step 3.6: Show the plots
plt.show()

# Define the fuzzy rules
rule1 = ctrl.Rule(amastigote_result['low'] & fields['high'], diagnosis['grade1'])
rule2 = ctrl.Rule(amastigote_result['medium'] & fields['medium'], diagnosis['grade2'])
rule3 = ctrl.Rule(amastigote_result['high'] & fields['medium'], diagnosis['grade3'])
rule4 = ctrl.Rule(amastigote_result['high'] & fields['high'], diagnosis['grade4'])

# Step 4.5: Print the fuzzy rules
print(diagnosis_ctrl.rules)

# Create the control system
diagnosis_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4])
diagnosis_sim = ctrl.ControlSystemSimulation(diagnosis_ctrl)

# Set input values
diagnosis_sim.input['amastigote_result'] = 8
diagnosis_sim.input['fields'] = 12

# Evaluate the control system
diagnosis_sim.compute()

# Print the output
print(diagnosis_sim.output['diagnosis'])
# Out:
# <skfuzzy.control.controlsystem.RuleOrderGenerator object at 0x7be2c8db9f90>
# 0.9500000000000002

# %% [markdown]
# # **This code is Just Written By F.Molaei Jahromi**
